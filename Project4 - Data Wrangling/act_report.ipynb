# %% [markdown]
# # Twitter Users Activity on WeRateDogs Portal

# %% [markdown]
# ## Data Analysis and Visualization

# %% [markdown]
# I downloaded the Twitter data for WeRateDogs website. The final dataset contains 2048 tweets. Mainly I focused on the retweet and favorites count. The distribution below shows with the actual data and log transformed data. I have transformed the data into log to make the distribution plot to near normal. From the below it clearly show that only very few tweets have higher Retweets and Favorites and marjority of them fall into right tail distribution.

# %%
from IPython.display import Image
Image(filename='RetweetsVSFavorites.png')

# %% [markdown]
# Checking to see if there is any correlations with the numeric attributes with a major focus on Favorites and Retweets.

# %%
from IPython.display import Image
Image(filename='corr_plot.png')

# %% [markdown]
# It looks like Retweets and Favorites are highly correlated. This shows that people who have retweeted have also done with
# favorites tag. Hence both the distributions shows similar behaviour.

# %% [markdown]
# To confirm the above behaviour, I plotted a scatter plot between Retweet and Favorites. Scatter plot shows that both the Retweets and Favorites go in sync together.

# %% [markdown]
# There is a very strong relationship between retweet and favorite counts. As the user shows interest on Favorites, then one can
# expect to see Retweets to increase and vice versa.

# %%
from IPython.display import Image
Image(filename='scatterplot.png')

# %% [markdown]
# Now the twitter look changed instead of favorite, it shows "like" option.

# %% [markdown]
# So from this we can also interpret that most of the users do a like or favorite because it acts like a bookmark which can help
# them to view again.

# %% [markdown]
# Retweets are not saved in the twitter profile. From the above analysis I got a good understanding about the website and also
# helped to learn about the different types of dog breeds avaialble in the world.

# %% [markdown]
# The image prediction output which shows the output produced from different algorithms.

# %%
from IPython.display import Image
Image(filename='Output_Predictions.png')

# %% [markdown]
# Majority of the predictions by 3 algoritms is done by golden_retriever, Labor_retriever and Chihuahua dogs.

# %%
from IPython.display import Image
Image(filename='Rating_Numerator.png')

# %%
Rating numerator have majority of ratings around 10. Except one rating around 170.

# %%
from IPython.display import Image
Image(filename='Rating_Denominator.png')

# %% [markdown]
# * Normally there must be rating denominator with only 10,but sometimes users with exaggeration(may be) rated with < 10 and > 10
# * So overall we have 16 records with the above scenario and all other tweets are rated on 10.
# * 2030 tweets have rating 10
